# %% [markdown]
# # STUDENT SCORE PREDICTION

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import seaborn as sns

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")

# %% [markdown]
# # 1. Basic Cleaning
# # Check missing values

# %%
print(df.isnull().sum())
df = df[['Hours_Studied', 'Exam_Score']].dropna()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# # 2. Basic Visualization

# %%
sns.lineplot(x='Hours_Studied', y='Exam_Score', data=df, marker='o')
plt.title('Study Hours vs Exam Score (Line Plot)')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.show()

# %% [markdown]
# # 3. Split dataset

# %%
X = df[['Hours_Studied']] 
y = df['Exam_Score']       

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# # 4. Train Linear Regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)

print("Coefficient (slope):", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Coefficient (slope): 0.28553906783754807
# Intercept: 61.538253404371844

# %% [markdown]
# # 5. Predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # 6. Visualization of Predictions

# %%
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Actual vs Predicted Exam Scores')
plt.legend()
plt.show()

# %% [markdown]
# # 7. Evaluation

# %%
mse = metrics.mean_squared_error(y_test,y_pred)
rmse = mse**0.5
r2 = metrics.r2_score(y_test,y_pred)
print("MSE:",mse)
print("RMSE:",rmse)
print("R2 Score:",r2)
# Out:
# MSE: 10.535841092033545
# RMSE: 3.245896038389638
# R2 Score: 0.23319773654271314
